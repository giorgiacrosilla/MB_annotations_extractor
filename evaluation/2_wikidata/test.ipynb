# %%
import os
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import time

# Read the CSV file
df = pd.read_csv(os.path.join(os.pardir, "preprocess", 'predicted_places.csv'))

# Initialize the SPARQL endpoint
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")



# Function to generate and run SPARQL query
def get_label(wikidata_id):
  query = f"""
  SELECT * WHERE {{
    wd:{wikidata_id} rdfs:label ?label ;
      schema:description ?description .
    FILTER (lang(?label) = "en")
    FILTER (lang(?description) = "en" || lang(?description) = "it")
  }}
  """
  sparql.setQuery(query)
  sparql.setReturnFormat(JSON)
  results = sparql.query().convert()
  time.sleep(.1)
  return results["results"]["bindings"][0] if results["results"]["bindings"] else None

# Iterate through each row and print the label
for index, row in df.iterrows():
  wikidata_url = row['wikidata_url']
  try:
    wikidata_id = wikidata_url.split("/")[-1]
    binding = get_label(wikidata_id)
    df.at[index, 'label'] = binding["label"]["value"]
    df.at[index, 'description'] = binding["description"]["value"]
  except Exception as e:
    print(f"URI: {wikidata_url}, Error: {e}")
    df.at[index, 'label'] = None
    df.at[index, 'description'] = None
    continue
  
# Save the DataFrame to a CSV file
df.drop(columns=['geonames_url'], inplace=True)
df.to_csv('test.csv', index=False)
# Out:
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3892513, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q1438759, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3637357, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3905046, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3901878, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q426609, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q628, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q6602, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q2449644, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q90, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q84, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q193193, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q207778, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q90, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q1731, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q1726, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3041446, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3041646, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q193563, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q3413229, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q32, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q812285, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q51252, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q1085126, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q51252, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q3892513, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q31613524, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q3892357, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q3556174, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q162633, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: nan, Error: 'float' object has no attribute 'split'
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q13364, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q3948391, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/N/A, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3892507, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q216479, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q1627767, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/, Error: 'NoneType' object is not subscriptable
# URI: nan, Error: 'float' object has no attribute 'split'
# URI: https://www.wikidata.org/wiki/Q3445, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q163687, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q2977, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q12280, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q130272, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q1160773, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q192982, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q82536, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3041646, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q3041646, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q7416, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q7750, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q1390519, Error: HTTP Error 429: Too Many Requests
# URI: https://www.wikidata.org/wiki/Q1277416, Error: 'NoneType' object is not subscriptable
# URI: https://www.wikidata.org/wiki/Q23482, Error: HTTP Error 429: Too Many Requests

# %%
import json
from openai import OpenAI
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

client = OpenAI(
  api_key=os.getenv("OPENAI_API_KEY"),  # This is the default and can be omitted
)

df = pd.read_csv('test.csv')

for index, row in df.iterrows():
  page = str(row['page'])
  value = row['value']
  label = row['label'] 
  wikidata_url = row['wikidata_url']
  description = row['description']
  try:
    with open(os.path.join(os.pardir, os.pardir, "txt", f"{page}.txt"), "r") as file:
      content = file.read()
  except FileNotFoundError:
    content = ""

  if not pd.isnull(label) and content:
    prompt = """
I am reviewing the following diary entry:

"""+content+"""

The system automatically detected that \""""+value+"""\" can be referenced as <"""+wikidata_url+""">.
This wikidata entry is about \""""+label+"""\" which is described as \""""+description+"""\".

Is this correct?
ANSWER ONLY WITH TRUE if the text is referring to the same place as the wikidata entry, FALSE if it is not, and UNCLEAR if it is not possible to determine
""" 
    chat_completion = client.chat.completions.create(
      messages=[
          {
              "role": "user",
              "content": prompt,
          }
      ],
      model="gpt-4o",
    )
    try:
      df.at[index, 'gpt-4o_result'] = chat_completion.choices[0].message.content
    except Exception as e:
      print(f"Error processing page {page}, value {value}: {e}")
      continue

df.to_csv('test_with_gpt.csv', index=False)
print("test_with_gpt.csv has been saved")
# Out:
# test_with_gpt.csv has been saved

# %%
# Read the CSV file
df = pd.read_csv('test_with_gpt.csv')

# Calculate TP, FP, FN
TP = len(df[(df['gpt-4o_result'] == 'TRUE') & (df['label'].notna())])
FP = len(df[(df['gpt-4o_result'].isin(['FALSE', 'UNCLEAR'])) & (df['label'].notna())])
FN = len(df[(df['gpt-4o_result'].isna()) & (df['label'].notna())])

# Calculate precision, recall, and F1 score
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"TP: {TP}, FP: {FP}, FN: {FN}")
print(f"Precision: {precision:.2%}, Recall: {recall:.2%}, F1 Score: {f1:.2%}")
# Out:
# TP: 252, FP: 92, FN: 0
# Precision: 73.26%, Recall: 100.00%, F1 Score: 84.56%
